# %%
cd /content/drive/MyDrive/Colab Notebooks/Github
# Out:
# /content/drive/MyDrive/Colab Notebooks/Github

# %%
# !git clone https://[Github 아이디]:[access token]@github.com/[Repository 주소]
# Out:
# Cloning into 'AI-Programming'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 629 bytes | 18.00 KiB/s, done.

# %%
cd /content/drive/MyDrive/Colab Notebooks/Github/AI-Programming
# Out:
# /content/drive/MyDrive/Colab Notebooks/Github/AI-Programming

# %%
# !git config --global user.email 'kkamboting@gmail.com'
# !git config --global user.name 'beeguriri'

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	assignment/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .
# !git commit -m"0403_python기초"
# !git push origin main
# Out:
# [main c4ad743] 0403_python기초
#  2 files changed, 2 insertions(+)
#  create mode 100644 Connection_to_Github.ipynb
#  create mode 100644 "lecture/0403_python \341\204\200\341\205\265\341\204\207\341\205\251\341\206\253.ipynb"
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 3.94 KiB | 576.00 KiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
# To https://github.com/beeguriri/AI-Programming.git
#    a0b59cf..c4ad743  main -> main
